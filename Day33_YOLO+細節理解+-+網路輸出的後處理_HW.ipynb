# %% [markdown]
# YOLO 網路輸出的後處理
#
# 在今天的課程，我們說明了 NMS 在 YOLO 中運作的情形：
# * 對每一個類別各別執行 NMS。
# 閾值* YOLO 在 NMS 中採用的信心度為：「每個 bounding box 所包含的各類別信心度」

# %% [markdown]
# 思考一下，閾值在 NMS 流程中，若將 IoU 的閾值（nms_threshold）調高，輸出的預測框會有什麼變化？
#
# 若 threshold 調高，預測框會變多，因為 IoU 小於 threshold 的 Boxes 會被保存下來
